# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))
url = "https://www.etf.com/etfanalytics/etf-finder"
driver.get(url)

# %%
time.sleep(5)
botao_100 = driver.find_element("xpath", '''html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]
/section[2]/div[1]/div/div[4]/button/label/span''')

driver.execute_script('arguments[0].click();', botao_100)

# %%
numero_paginas = driver.find_element("xpath", '''html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
/section[2]/div[2]/section[2]/div[2]/div/label[2]''')
numero_paginas = int(numero_paginas.text.replace("of ",""))
numero_paginas
# Out:
# 31

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]
    /section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
base_de_dados_completa = pd.concat(lista_de_tabela_por_pagina)

base_de_dados_completa
# Out:
#    Ticker                                        Name  \
# 0     SPY                      SPDR S&P 500 ETF Trust
# 1     IVV                    iShares Core S&P 500 ETF
# 2     VTI             Vanguard Total Stock Market ETF
# 3     VOO                        Vanguard S&P 500 ETF
# 4     QQQ                           Invesco QQQ Trust
# ..    ...                                         ...
# 85   AWYX              ETFMG 2x Daily Travel Tech ETF
# 86   TADS               The Active Dividend Stock ETF
# 87   CRYP  AdvisorShares Managed Bitcoin Strategy ETF
# 88   FLRU                    Franklin FTSE Russia ETF
# 89   NBCM     Neuberger Berman Commodity Strategy ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 85  Leveraged Equity: Global Internet & Direct Mar...
# 86                        Equity: U.S. - Total Market
# 87            Asset Allocation: Global Target Outcome
# 88                      Equity: Russia - Total Market
# 89                          Commodities: Broad Market
#
#                              Issuer Expense Ratio       AUM
# 0      State Street Global Advisors         0.09%  $384.58B
# 1                         Blackrock         0.03%  $313.53B
# 2                          Vanguard         0.03%  $287.40B
# 3                          Vanguard         0.03%  $285.32B
# 4                           Invesco         0.20%  $164.12B
# ..                              ...           ...       ...
# 85                            ETFMG         0.95%  $341.97K
# 86  Tuttle Tactical Management, LLC         1.68%  $294.89K
# 87                    AdvisorShares         1.59%  $217.68K
# 88               Franklin Templeton         0.19%    $8.00K
# 89                 Neuberger Berman         0.65%        --
#
# [3090 rows x 6 columns]

# %%
botao_performance = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
/section[2]/div[2]/ul/li[2]/span''')

driver.execute_script("arguments[0].click();", botao_performance)

for pagina in range (0, numero_paginas):
    
    botao_voltar = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
    /section[2]/div[2]/section[2]/div[2]/div/span[1]''')
    
    driver.execute_script("arguments[0].click();", botao_voltar)

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]
    /section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
base_de_dados_performance = pd.concat(lista_de_tabela_por_pagina)

base_de_dados_performance
# Out:
#    Ticker                                        Name 1 Month 3 Month     YTD  \
# 0     SPY                      SPDR S&P 500 ETF Trust   4.03%   8.84%   3.52%
# 1     IVV                    iShares Core S&P 500 ETF   4.06%   8.84%   3.51%
# 2     VTI             Vanguard Total Stock Market ETF   4.49%   8.98%   3.96%
# 3     VOO                        Vanguard S&P 500 ETF   4.02%   8.82%   3.52%
# 4     QQQ                           Invesco QQQ Trust   4.88%   5.30%   6.16%
# ..    ...                                         ...     ...     ...     ...
# 85   AWYX              ETFMG 2x Daily Travel Tech ETF  36.11%  38.66%  31.27%
# 86   TADS               The Active Dividend Stock ETF      0%      0%      0%
# 87   CRYP  AdvisorShares Managed Bitcoin Strategy ETF      --      --      --
# 88   FLRU                    Franklin FTSE Russia ETF      0%      0%      0%
# 89   NBCM     Neuberger Berman Commodity Strategy ETF   4.82%      --   1.82%
#
#      1 Year  3 Years 5 Years 10 Years As Of Date
# 0    -9.95%    7.75%   8.99%   12.39%   01/20/23
# 1    -9.95%    7.75%   9.03%   12.44%   01/20/23
# 2   -10.36%    7.24%   8.49%   12.02%   01/20/23
# 3    -9.98%    7.73%   9.02%   12.44%   01/20/23
# 4   -21.28%    8.84%  11.98%   16.55%   01/20/23
# ..      ...      ...     ...      ...        ...
# 85  -48.46%       --      --       --   01/20/23
# 86       0%       --      --       --   01/20/23
# 87       --       --      --       --   01/20/23
# 88  -66.37%  -31.18%      --       --   01/20/23
# 89       --       --      --       --   01/20/23
#
# [3090 rows x 10 columns]

# %%
base_de_dados_completa = base_de_dados_completa.set_index("Ticker")

base_de_dados_completa
# Out:
#                                               Name  \
# Ticker
# SPY                         SPDR S&P 500 ETF Trust
# IVV                       iShares Core S&P 500 ETF
# VTI                Vanguard Total Stock Market ETF
# VOO                           Vanguard S&P 500 ETF
# QQQ                              Invesco QQQ Trust
# ...                                            ...
# AWYX                ETFMG 2x Daily Travel Tech ETF
# TADS                 The Active Dividend Stock ETF
# CRYP    AdvisorShares Managed Bitcoin Strategy ETF
# FLRU                      Franklin FTSE Russia ETF
# NBCM       Neuberger Berman Commodity Strategy ETF
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# AWYX    Leveraged Equity: Global Internet & Direct Mar...
# TADS                          Equity: U.S. - Total Market
# CRYP              Asset Allocation: Global Target Outcome
# FLRU                        Equity: Russia - Total Market
# NBCM                            Commodities: Broad Market
#
#                                  Issuer Expense Ratio       AUM
# Ticker
# SPY        State Street Global Advisors         0.09%  $384.58B
# IVV                           Blackrock         0.03%  $313.53B
# VTI                            Vanguard         0.03%  $287.40B
# VOO                            Vanguard         0.03%  $285.32B
# QQQ                             Invesco         0.20%  $164.12B
# ...                                 ...           ...       ...
# AWYX                              ETFMG         0.95%  $341.97K
# TADS    Tuttle Tactical Management, LLC         1.68%  $294.89K
# CRYP                      AdvisorShares         1.59%  $217.68K
# FLRU                 Franklin Templeton         0.19%    $8.00K
# NBCM                   Neuberger Berman         0.65%        --
#
# [3090 rows x 5 columns]

# %%
base_de_dados_performance = base_de_dados_performance.set_index("Ticker")
base_de_dados_performance = base_de_dados_performance[['3 Years','5 Years','10 Years']]
base_de_dados_performance
# Out:
#         3 Years 5 Years 10 Years
# Ticker
# SPY       7.75%   8.99%   12.39%
# IVV       7.75%   9.03%   12.44%
# VTI       7.24%   8.49%   12.02%
# VOO       7.73%   9.02%   12.44%
# QQQ       8.84%  11.98%   16.55%
# ...         ...     ...      ...
# AWYX         --      --       --
# TADS         --      --       --
# CRYP         --      --       --
# FLRU    -31.18%      --       --
# NBCM         --      --       --
#
# [3090 rows x 3 columns]

# %%
base_de_dados_performance = base_de_dados_performance.replace("--",pd.NA)

base_de_dados_performance
# Out:
#         3 Years 5 Years 10 Years
# Ticker
# SPY       7.75%   8.99%   12.39%
# IVV       7.75%   9.03%   12.44%
# VTI       7.24%   8.49%   12.02%
# VOO       7.73%   9.02%   12.44%
# QQQ       8.84%  11.98%   16.55%
# ...         ...     ...      ...
# AWYX       <NA>     NaN      NaN
# TADS       <NA>     NaN      NaN
# CRYP       <NA>     NaN      NaN
# FLRU    -31.18%     NaN      NaN
# NBCM       <NA>     NaN      NaN
#
# [3090 rows x 3 columns]

# %%
base_de_dados_performance = base_de_dados_performance.dropna()

base_de_dados_performance
# Out:
#         3 Years  5 Years 10 Years
# Ticker
# SPY       7.75%    8.99%   12.39%
# IVV       7.75%    9.03%   12.44%
# VTI       7.24%    8.49%   12.02%
# VOO       7.73%    9.02%   12.44%
# QQQ       8.84%   11.98%   16.55%
# ...         ...      ...      ...
# SZK     -26.41%  -20.50%  -22.95%
# LD        2.50%   -5.95%   -1.99%
# ERUS    -41.79%  -23.10%  -13.14%
# LTL      -6.32%   -2.87%    2.44%
# RSXJ    -31.36%  -20.41%  -10.41%
#
# [894 rows x 3 columns]

# %%
for i in base_de_dados_performance.columns:

    base_de_dados_performance[i] = base_de_dados_performance[i].str.rstrip('%').astype(float)/100

base_de_dados_performance
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_21280\41144121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_performance[i] = base_de_dados_performance[i].str.rstrip('%').astype(float)/100
#         3 Years  5 Years  10 Years
# Ticker
# SPY      0.0775   0.0899    0.1239
# IVV      0.0775   0.0903    0.1244
# VTI      0.0724   0.0849    0.1202
# VOO      0.0773   0.0902    0.1244
# QQQ      0.0884   0.1198    0.1655
# ...         ...      ...       ...
# SZK     -0.2641  -0.2050   -0.2295
# LD       0.0250  -0.0595   -0.0199
# ERUS    -0.4179  -0.2310   -0.1314
# LTL     -0.0632  -0.0287    0.0244
# RSXJ    -0.3136  -0.2041   -0.1041
#
# [894 rows x 3 columns]

# %%
base_de_dados_final = base_de_dados_completa.join(base_de_dados_performance, how = "inner")
base_de_dados_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# LTL                 ProShares Ultra Telecommunications
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# LTL           Leveraged Equity: U.S. Telecoms                     ProShares
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years
# Ticker
# SPY            0.09%  $384.58B   0.0775   0.0899    0.1239
# IVV            0.03%  $313.53B   0.0775   0.0903    0.1244
# VTI            0.03%  $287.40B   0.0724   0.0849    0.1202
# VOO            0.03%  $285.32B   0.0773   0.0902    0.1244
# QQQ            0.20%  $164.12B   0.0884   0.1198    0.1655
# ...              ...       ...      ...      ...       ...
# SZK            0.95%    $1.28M  -0.2641  -0.2050   -0.2295
# LD             0.70%    $1.23M   0.0250  -0.0595   -0.0199
# ERUS           0.08%  $961.13K  -0.4179  -0.2310   -0.1314
# LTL            0.95%  $686.95K  -0.0632  -0.0287    0.0244
# RSXJ           0.67%  $387.25K  -0.3136  -0.2041   -0.1041
#
# [894 rows x 8 columns]

# %%
base_de_dados_final = base_de_dados_final[~base_de_dados_final['Segment'].str.contains("Leveraged")]
base_de_dados_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years
# Ticker
# SPY            0.09%  $384.58B   0.0775   0.0899    0.1239
# IVV            0.03%  $313.53B   0.0775   0.0903    0.1244
# VTI            0.03%  $287.40B   0.0724   0.0849    0.1202
# VOO            0.03%  $285.32B   0.0773   0.0902    0.1244
# QQQ            0.20%  $164.12B   0.0884   0.1198    0.1655
# ...              ...       ...      ...      ...       ...
# RXD            0.95%    $1.92M  -0.2775  -0.2535   -0.2925
# SZK            0.95%    $1.28M  -0.2641  -0.2050   -0.2295
# LD             0.70%    $1.23M   0.0250  -0.0595   -0.0199
# ERUS           0.08%  $961.13K  -0.4179  -0.2310   -0.1314
# RSXJ           0.67%  $387.25K  -0.3136  -0.2041   -0.1041
#
# [836 rows x 8 columns]

# %%
base_de_dados_final['rank_3_anos'] = base_de_dados_final['3 Years'].rank(ascending = False)
base_de_dados_final['rank_5_anos'] = base_de_dados_final['5 Years'].rank(ascending = False)
base_de_dados_final['rank_10_anos'] = base_de_dados_final['10 Years'].rank(ascending = False)

base_de_dados_final
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_21280\2550834387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_3_anos'] = base_de_dados_final['3 Years'].rank(ascending = False)
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_21280\2550834387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_5_anos'] = base_de_dados_final['5 Years'].rank(ascending = False)
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_21280\2550834387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_10_anos'] = base_de_dados_final['10 Years'].rank(ascending = False)
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years  rank_3_anos  \
# Ticker
# SPY            0.09%  $384.58B   0.0775   0.0899    0.1239        202.0
# IVV            0.03%  $313.53B   0.0775   0.0903    0.1244        202.0
# VTI            0.03%  $287.40B   0.0724   0.0849    0.1202        235.0
# VOO            0.03%  $285.32B   0.0773   0.0902    0.1244        204.5
# QQQ            0.20%  $164.12B   0.0884   0.1198    0.1655        151.0
# ...              ...       ...      ...      ...       ...          ...
# RXD            0.95%    $1.92M  -0.2775  -0.2535   -0.2925        805.0
# SZK            0.95%    $1.28M  -0.2641  -0.2050   -0.2295        804.0
# LD             0.70%    $1.23M   0.0250  -0.0595   -0.0199        451.0
# ERUS           0.08%  $961.13K  -0.4179  -0.2310   -0.1314        821.0
# RSXJ           0.67%  $387.25K  -0.3136  -0.2041   -0.1041        811.0
#
#         rank_5_anos  rank_10_anos
# Ticker
# SPY           108.0          78.5
# IVV           101.5          76.0
# VTI           137.0         104.5
# VOO           104.0          76.0
# QQQ            22.0          13.0
# ...             ...           ...
# RXD           811.0         818.0
# SZK           801.0         807.0
# LD            760.0         703.5
# ERUS          805.0         790.0
# RSXJ          800.0         779.0
#
# [836 rows x 11 columns]

# %%
base_de_dados_final['rank_final'] = base_de_dados_final['rank_3_anos'] + base_de_dados_final['rank_5_anos'] + base_de_dados_final['rank_10_anos'] 
base_de_dados_final
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_21280\1945516042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_final'] = base_de_dados_final['rank_3_anos'] + base_de_dados_final['rank_5_anos'] + base_de_dados_final['rank_10_anos']
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years  rank_3_anos  \
# Ticker
# SPY            0.09%  $384.58B   0.0775   0.0899    0.1239        202.0
# IVV            0.03%  $313.53B   0.0775   0.0903    0.1244        202.0
# VTI            0.03%  $287.40B   0.0724   0.0849    0.1202        235.0
# VOO            0.03%  $285.32B   0.0773   0.0902    0.1244        204.5
# QQQ            0.20%  $164.12B   0.0884   0.1198    0.1655        151.0
# ...              ...       ...      ...      ...       ...          ...
# RXD            0.95%    $1.92M  -0.2775  -0.2535   -0.2925        805.0
# SZK            0.95%    $1.28M  -0.2641  -0.2050   -0.2295        804.0
# LD             0.70%    $1.23M   0.0250  -0.0595   -0.0199        451.0
# ERUS           0.08%  $961.13K  -0.4179  -0.2310   -0.1314        821.0
# RSXJ           0.67%  $387.25K  -0.3136  -0.2041   -0.1041        811.0
#
#         rank_5_anos  rank_10_anos  rank_final
# Ticker
# SPY           108.0          78.5       388.5
# IVV           101.5          76.0       379.5
# VTI           137.0         104.5       476.5
# VOO           104.0          76.0       384.5
# QQQ            22.0          13.0       186.0
# ...             ...           ...         ...
# RXD           811.0         818.0      2434.0
# SZK           801.0         807.0      2412.0
# LD            760.0         703.5      1914.5
# ERUS          805.0         790.0      2416.0
# RSXJ          800.0         779.0      2390.0
#
# [836 rows x 12 columns]
