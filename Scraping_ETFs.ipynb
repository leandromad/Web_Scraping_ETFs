# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))
url = "https://www.etf.com/etfanalytics/etf-finder"
driver.get(url)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.78M/6.78M [00:00<00:00, 54.7MB/s]

# %%
time.sleep(5)
botao_100 = driver.find_element("xpath", '''html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]
/section[2]/div[1]/div/div[4]/button/label/span''')

driver.execute_script('arguments[0].click();', botao_100)

# %%
numero_paginas = driver.find_element("xpath", '''html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
/section[2]/div[2]/section[2]/div[2]/div/label[2]''')
numero_paginas = int(numero_paginas.text.replace("of ",""))
numero_paginas
# Out:
# 32

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]
    /section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
base_de_dados_completa = pd.concat(lista_de_tabela_por_pagina)

base_de_dados_completa
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF
# 11   CVIE        Calvert International Responsible Index ETF
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 8   Fixed Income: Global - Broad Market, Broad-bas...
# 9                            Equity: U.S. - Large Cap
# 10                             Equity: U.S. - Mid Cap
# 11      Equity: Developed Markets Ex-U.S. - Large Cap
# 12                           Equity: U.S. - Large Cap
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $379.11B
# 1                      Blackrock         0.03%  $310.04B
# 2                       Vanguard         0.03%  $284.32B
# 3                       Vanguard         0.03%  $282.26B
# 4                        Invesco         0.20%  $161.85B
# ..                           ...           ...       ...
# 8                 Morgan Stanley         0.24%        --
# 9                 Morgan Stanley            --        --
# 10                Morgan Stanley         0.15%        --
# 11                Morgan Stanley            --        --
# 12                Morgan Stanley            --        --
#
# [3113 rows x 6 columns]

# %%
botao_performance = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
/section[2]/div[2]/ul/li[2]/span''')

driver.execute_script("arguments[0].click();", botao_performance)

for pagina in range (0, numero_paginas):
    
    botao_voltar = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]
    /section[2]/div[2]/section[2]/div[2]/div/span[1]''')
    
    driver.execute_script("arguments[0].click();", botao_voltar)

# %%
lista_de_tabela_por_pagina = []

for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]
    /section/div/div/div/div/div[2]/section[2]/div[2]/div/table''')

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista_de_tabela_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
base_de_dados_performance = pd.concat(lista_de_tabela_por_pagina)

base_de_dados_performance
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   4.96%   9.32%
# 1     IVV                           iShares Core S&P 500 ETF   5.01%   9.33%
# 2     VTI                    Vanguard Total Stock Market ETF   5.42%   9.66%
# 3     VOO                               Vanguard S&P 500 ETF   4.99%   9.31%
# 4     QQQ                                  Invesco QQQ Trust  11.51%  14.85%
# ..    ...                                                ...     ...     ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF      --      --
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF      --      --
# 11   CVIE        Calvert International Responsible Index ETF      --      --
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...      --      --
#
#        YTD   1 Year 3 Years 5 Years 10 Years As Of Date
# 0    6.45%   -9.58%   8.73%  11.15%   12.44%   02/09/23
# 1    6.47%   -9.55%   8.74%  11.17%   12.50%   02/09/23
# 2    7.03%  -10.06%   8.29%  10.66%   12.08%   02/09/23
# 3    6.48%   -9.57%   8.71%  11.17%   12.50%   02/09/23
# 4   13.29%  -17.13%  10.27%  14.91%   17.15%   02/09/23
# ..     ...      ...     ...     ...      ...        ...
# 8       --       --      --      --       --   02/09/23
# 9       --       --      --      --       --   02/09/23
# 10      --       --      --      --       --   02/09/23
# 11      --       --      --      --       --   02/09/23
# 12      --       --      --      --       --   02/09/23
#
# [3113 rows x 10 columns]

# %%
base_de_dados_completa = base_de_dados_completa.set_index("Ticker")

base_de_dados_completa
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B
# IVV                        Blackrock         0.03%  $310.04B
# VTI                         Vanguard         0.03%  $284.32B
# VOO                         Vanguard         0.03%  $282.26B
# QQQ                          Invesco         0.20%  $161.85B
# ...                              ...           ...       ...
# CVSB                  Morgan Stanley         0.24%        --
# CVLC                  Morgan Stanley            --        --
# CVMC                  Morgan Stanley         0.15%        --
# CVIE                  Morgan Stanley            --        --
# CDEI                  Morgan Stanley            --        --
#
# [3113 rows x 5 columns]

# %%
base_de_dados_performance = base_de_dados_performance.set_index("Ticker")
base_de_dados_performance = base_de_dados_performance[['3 Years','5 Years','10 Years']]
base_de_dados_performance
# Out:
#        3 Years 5 Years 10 Years
# Ticker
# SPY      8.73%  11.15%   12.44%
# IVV      8.74%  11.17%   12.50%
# VTI      8.29%  10.66%   12.08%
# VOO      8.71%  11.17%   12.50%
# QQQ     10.27%  14.91%   17.15%
# ...        ...     ...      ...
# CVSB        --      --       --
# CVLC        --      --       --
# CVMC        --      --       --
# CVIE        --      --       --
# CDEI        --      --       --
#
# [3113 rows x 3 columns]

# %%
base_de_dados_performance = base_de_dados_performance.replace("--",pd.NA)

base_de_dados_performance
# Out:
#        3 Years 5 Years 10 Years
# Ticker
# SPY      8.73%  11.15%   12.44%
# IVV      8.74%  11.17%   12.50%
# VTI      8.29%  10.66%   12.08%
# VOO      8.71%  11.17%   12.50%
# QQQ     10.27%  14.91%   17.15%
# ...        ...     ...      ...
# CVSB       NaN     NaN      NaN
# CVLC       NaN     NaN      NaN
# CVMC       NaN     NaN      NaN
# CVIE       NaN     NaN      NaN
# CDEI       NaN     NaN      NaN
#
# [3113 rows x 3 columns]

# %%
base_de_dados_performance = base_de_dados_performance.dropna()

base_de_dados_performance
# Out:
#         3 Years  5 Years 10 Years
# Ticker
# SPY       8.73%   11.15%   12.44%
# IVV       8.74%   11.17%   12.50%
# VTI       8.29%   10.66%   12.08%
# VOO       8.71%   11.17%   12.50%
# QQQ      10.27%   14.91%   17.15%
# ...         ...      ...      ...
# SZK     -29.19%  -24.71%  -23.59%
# LD        6.45%   -5.28%   -2.39%
# ERUS    -40.02%  -21.93%  -13.00%
# LTL      -6.36%   -1.09%    2.05%
# RSXJ    -31.23%  -19.51%  -10.81%
#
# [894 rows x 3 columns]

# %%
for i in base_de_dados_performance.columns:

    base_de_dados_performance[i] = base_de_dados_performance[i].str.rstrip('%').astype(float)/100

base_de_dados_performance
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_15712\41144121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_performance[i] = base_de_dados_performance[i].str.rstrip('%').astype(float)/100
#         3 Years  5 Years  10 Years
# Ticker
# SPY      0.0873   0.1115    0.1244
# IVV      0.0874   0.1117    0.1250
# VTI      0.0829   0.1066    0.1208
# VOO      0.0871   0.1117    0.1250
# QQQ      0.1027   0.1491    0.1715
# ...         ...      ...       ...
# SZK     -0.2919  -0.2471   -0.2359
# LD       0.0645  -0.0528   -0.0239
# ERUS    -0.4002  -0.2193   -0.1300
# LTL     -0.0636  -0.0109    0.0205
# RSXJ    -0.3123  -0.1951   -0.1081
#
# [894 rows x 3 columns]

# %%
base_de_dados_final = base_de_dados_completa.join(base_de_dados_performance, how = "inner")
base_de_dados_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# LTL                 ProShares Ultra Telecommunications
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# LTL           Leveraged Equity: U.S. Telecoms                     ProShares
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years
# Ticker
# SPY            0.09%  $379.11B   0.0873   0.1115    0.1244
# IVV            0.03%  $310.04B   0.0874   0.1117    0.1250
# VTI            0.03%  $284.32B   0.0829   0.1066    0.1208
# VOO            0.03%  $282.26B   0.0871   0.1117    0.1250
# QQQ            0.20%  $161.85B   0.1027   0.1491    0.1715
# ...              ...       ...      ...      ...       ...
# SZK            0.95%    $1.30M  -0.2919  -0.2471   -0.2359
# LD             0.70%    $1.24M   0.0645  -0.0528   -0.0239
# ERUS           0.08%  $961.13K  -0.4002  -0.2193   -0.1300
# LTL            0.95%  $668.72K  -0.0636  -0.0109    0.0205
# RSXJ           0.67%  $387.25K  -0.3123  -0.1951   -0.1081
#
# [894 rows x 8 columns]

# %%
base_de_dados_final = base_de_dados_final[~base_de_dados_final['Segment'].str.contains("Leveraged")]
base_de_dados_final
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years
# Ticker
# SPY            0.09%  $379.11B   0.0873   0.1115    0.1244
# IVV            0.03%  $310.04B   0.0874   0.1117    0.1250
# VTI            0.03%  $284.32B   0.0829   0.1066    0.1208
# VOO            0.03%  $282.26B   0.0871   0.1117    0.1250
# QQQ            0.20%  $161.85B   0.1027   0.1491    0.1715
# ...              ...       ...      ...      ...       ...
# RXD            0.95%    $1.94M  -0.2726  -0.2685   -0.2854
# SZK            0.95%    $1.30M  -0.2919  -0.2471   -0.2359
# LD             0.70%    $1.24M   0.0645  -0.0528   -0.0239
# ERUS           0.08%  $961.13K  -0.4002  -0.2193   -0.1300
# RSXJ           0.67%  $387.25K  -0.3123  -0.1951   -0.1081
#
# [836 rows x 8 columns]

# %%
base_de_dados_final['rank_3_anos'] = base_de_dados_final['3 Years'].rank(ascending = False)
base_de_dados_final['rank_5_anos'] = base_de_dados_final['5 Years'].rank(ascending = False)
base_de_dados_final['rank_10_anos'] = base_de_dados_final['10 Years'].rank(ascending = False)

base_de_dados_final
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_15712\2550834387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_3_anos'] = base_de_dados_final['3 Years'].rank(ascending = False)
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_15712\2550834387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_5_anos'] = base_de_dados_final['5 Years'].rank(ascending = False)
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_15712\2550834387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_10_anos'] = base_de_dados_final['10 Years'].rank(ascending = False)
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years  rank_3_anos  \
# Ticker
# SPY            0.09%  $379.11B   0.0873   0.1115    0.1244        205.0
# IVV            0.03%  $310.04B   0.0874   0.1117    0.1250        204.0
# VTI            0.03%  $284.32B   0.0829   0.1066    0.1208        238.5
# VOO            0.03%  $282.26B   0.0871   0.1117    0.1250        207.0
# QQQ            0.20%  $161.85B   0.1027   0.1491    0.1715        149.5
# ...              ...       ...      ...      ...       ...          ...
# RXD            0.95%    $1.94M  -0.2726  -0.2685   -0.2854        804.0
# SZK            0.95%    $1.30M  -0.2919  -0.2471   -0.2359        806.0
# LD             0.70%    $1.24M   0.0645  -0.0528   -0.0239        345.0
# ERUS           0.08%  $961.13K  -0.4002  -0.2193   -0.1300        817.0
# RSXJ           0.67%  $387.25K  -0.3123  -0.1951   -0.1081        809.0
#
#         rank_5_anos  rank_10_anos
# Ticker
# SPY            97.0          77.0
# IVV            93.5          74.5
# VTI           119.5         100.0
# VOO            93.5          74.5
# QQQ            19.0          11.0
# ...             ...           ...
# RXD           809.0         818.0
# SZK           806.0         807.0
# LD            759.0         709.0
# ERUS          803.0         788.0
# RSXJ          799.5         778.0
#
# [836 rows x 11 columns]

# %%
base_de_dados_final['rank_final'] = base_de_dados_final['rank_3_anos'] + base_de_dados_final['rank_5_anos'] + base_de_dados_final['rank_10_anos'] 
base_de_dados_final
# Out:
# C:\Users\Pichau\AppData\Local\Temp\ipykernel_15712\1945516042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_de_dados_final['rank_final'] = base_de_dados_final['rank_3_anos'] + base_de_dados_final['rank_5_anos'] + base_de_dados_final['rank_10_anos']
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# RXD                   ProShares UltraShort Health Care
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# RXD          Inverse Equity: U.S. Health Care                     ProShares
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years  rank_3_anos  \
# Ticker
# SPY            0.09%  $379.11B   0.0873   0.1115    0.1244        205.0
# IVV            0.03%  $310.04B   0.0874   0.1117    0.1250        204.0
# VTI            0.03%  $284.32B   0.0829   0.1066    0.1208        238.5
# VOO            0.03%  $282.26B   0.0871   0.1117    0.1250        207.0
# QQQ            0.20%  $161.85B   0.1027   0.1491    0.1715        149.5
# ...              ...       ...      ...      ...       ...          ...
# RXD            0.95%    $1.94M  -0.2726  -0.2685   -0.2854        804.0
# SZK            0.95%    $1.30M  -0.2919  -0.2471   -0.2359        806.0
# LD             0.70%    $1.24M   0.0645  -0.0528   -0.0239        345.0
# ERUS           0.08%  $961.13K  -0.4002  -0.2193   -0.1300        817.0
# RSXJ           0.67%  $387.25K  -0.3123  -0.1951   -0.1081        809.0
#
#         rank_5_anos  rank_10_anos  rank_final
# Ticker
# SPY            97.0          77.0       379.0
# IVV            93.5          74.5       372.0
# VTI           119.5         100.0       458.0
# VOO            93.5          74.5       375.0
# QQQ            19.0          11.0       179.5
# ...             ...           ...         ...
# RXD           809.0         818.0      2431.0
# SZK           806.0         807.0      2419.0
# LD            759.0         709.0      1813.0
# ERUS          803.0         788.0      2408.0
# RSXJ          799.5         778.0      2386.5
#
# [836 rows x 12 columns]

# %%
melhores_etfs = base_de_dados_final.sort_values(by = 'rank_final')
melhores_etfs
# Out:
#                                                      Name  \
# Ticker
# XSD                            SPDR S&P Semiconductor ETF
# TAN                                     Invesco Solar ETF
# QCLN    First Trust NASDAQ Clean Edge Green Energy Ind...
# SMH                              VanEck Semiconductor ETF
# PSI                    Invesco Dynamic Semiconductors ETF
# ...                                                   ...
# FAZ               Direxion Daily Financial Bear 3X Shares
# SSG                   ProShares UltraShort Semiconductors
# DUST      Direxion Daily Gold Miners Index Bear 2x Shares
# SQQQ                         ProShares UltraPro Short QQQ
# TECS             Direxion Daily Technology Bear 3X Shares
#
#                                             Segment  \
# Ticker
# XSD                     Equity: U.S. Semiconductors
# TAN                 Equity: Global Renewable Energy
# QCLN                  Equity: U.S. Renewable Energy
# SMH                   Equity: Global Semiconductors
# PSI                     Equity: U.S. Semiconductors
# ...                                             ...
# FAZ                 Inverse Equity: U.S. Financials
# SSG             Inverse Equity: U.S. Semiconductors
# DUST             Inverse Equity: Global Gold Miners
# SQQQ               Inverse Equity: U.S. - Large Cap
# TECS    Inverse Equity: U.S. Information Technology
#
#                               Issuer Expense Ratio       AUM  3 Years  \
# Ticker
# XSD     State Street Global Advisors         0.35%    $1.33B   0.2510
# TAN                          Invesco         0.69%    $2.49B   0.2993
# QCLN                     First Trust         0.58%    $1.85B   0.2641
# SMH                           VanEck         0.35%    $7.70B   0.2092
# PSI                          Invesco         0.56%  $546.43M   0.2037
# ...                              ...           ...       ...      ...
# FAZ                         Direxion         1.01%  $171.15M  -0.5703
# SSG                        ProShares         0.95%    $6.70M  -0.5823
# DUST                        Direxion         0.92%  $113.59M  -0.5590
# SQQQ                       ProShares         0.95%    $4.95B  -0.5642
# TECS                        Direxion         1.01%  $146.14M  -0.6309
#
#         5 Years  10 Years  rank_3_anos  rank_5_anos  rank_10_anos  rank_final
# Ticker
# XSD      0.2602    0.2436         17.0          2.0           1.0        20.0
# TAN      0.2809    0.1702          8.0          1.0          12.5        21.5
# QCLN     0.2482    0.1858         13.0          3.0           6.0        22.0
# SMH      0.2189    0.2311         31.0          4.0           4.0        39.0
# PSI      0.2031    0.2363         32.0          6.0           2.0        40.0
# ...         ...       ...          ...          ...           ...         ...
# FAZ     -0.4917   -0.4589        832.0        832.0         831.0      2495.0
# SSG     -0.5210   -0.4805        833.0        833.0         833.0      2499.0
# DUST    -0.5494   -0.5277        830.0        834.0         835.0      2499.0
# SQQQ    -0.5513   -0.5184        831.0        835.0         834.0      2500.0
# TECS    -0.6171   -0.5504        836.0        836.0         836.0      2508.0
#
# [836 rows x 12 columns]

# %%
melhores_etfs.head(10)
# Out:
#                                                      Name  \
# Ticker
# XSD                            SPDR S&P Semiconductor ETF
# TAN                                     Invesco Solar ETF
# QCLN    First Trust NASDAQ Clean Edge Green Energy Ind...
# SMH                              VanEck Semiconductor ETF
# PSI                    Invesco Dynamic Semiconductors ETF
# SOXX                            iShares Semiconductor ETF
# PTF                   Invesco DWA Technology Momentum ETF
# XLK                    Technology Select Sector SPDR Fund
# GRID    First Trust NASDAQ Clean Edge Smart Grid Infra...
# SPHB                        Invesco S&P 500 High Beta ETF
#
#                                     Segment                        Issuer  \
# Ticker
# XSD             Equity: U.S. Semiconductors  State Street Global Advisors
# TAN         Equity: Global Renewable Energy                       Invesco
# QCLN          Equity: U.S. Renewable Energy                   First Trust
# SMH           Equity: Global Semiconductors                        VanEck
# PSI             Equity: U.S. Semiconductors                       Invesco
# SOXX            Equity: U.S. Semiconductors                     Blackrock
# PTF     Equity: U.S. Information Technology                       Invesco
# XLK     Equity: U.S. Information Technology  State Street Global Advisors
# GRID          Equity: Global Infrastructure                   First Trust
# SPHB               Equity: U.S. - Large Cap                       Invesco
#
#        Expense Ratio       AUM  3 Years  5 Years  10 Years  rank_3_anos  \
# Ticker
# XSD            0.35%    $1.33B   0.2510   0.2602    0.2436         17.0
# TAN            0.69%    $2.49B   0.2993   0.2809    0.1702          8.0
# QCLN           0.58%    $1.85B   0.2641   0.2482    0.1858         13.0
# SMH            0.35%    $7.70B   0.2092   0.2189    0.2311         31.0
# PSI            0.56%  $546.43M   0.2037   0.2031    0.2363         32.0
# SOXX           0.35%    $7.30B   0.1991   0.2144    0.2360         35.0
# PTF            0.60%  $218.33M   0.1511   0.1880    0.1628         68.0
# XLK            0.10%   $42.35B   0.1334   0.1865    0.1849         82.0
# GRID           0.58%  $707.91M   0.2013   0.1562    0.1321         33.0
# SPHB           0.25%  $717.64M   0.1879   0.1423    0.1354         39.0
#
#         rank_5_anos  rank_10_anos  rank_final
# Ticker
# XSD             2.0           1.0        20.0
# TAN             1.0          12.5        21.5
# QCLN            3.0           6.0        22.0
# SMH             4.0           4.0        39.0
# PSI             6.0           2.0        40.0
# SOXX            5.0           3.0        43.0
# PTF             8.0          16.0        92.0
# XLK             9.0           7.0        98.0
# GRID           16.0          54.5       103.5
# SPHB           22.0          43.5       104.5
